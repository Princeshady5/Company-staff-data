# %% [raw]
# import data file

# %%
import pandas as pd
import xlrd
import openpyxl

# %% [markdown]
# Our excelf file comprise of 3 sheets with the test data in sheet 2 and train data in sheet 3.
# To view sheet 3, we parse the sheet name

# %%
emp_left = pd.read_excel("TakenMind-Python-Analytics-Problem-case-study-1-1.xlsx",  sheet_name= "Employees who have left")
print (emp_left.head())
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.38             0.53               2
# 1       2                0.80             0.86               5
# 2       3                0.11             0.88               7
# 3       4                0.72             0.87               5
# 4       5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years   dept  salary
# 0                      0  sales     low
# 1                      0  sales  medium
# 2                      0  sales  medium
# 3                      0  sales     low
# ...

# %% [markdown]
# check for shape and missing values

# %%
print (emp_left.shape)
# Out:
# (3571, 10)

# %%
print (emp_left.isna().sum())
# Out:
# Emp ID                   0
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# dept                     0
# salary                   0
# dtype: int64

# %% [markdown]
# we do not haver missing values. we can go on to work on the data. our target variable,y, is number of yours an emplyee stays in the company while x will be other attributes. we see that the emplyee ID has no effect on the outcome therefore we can drop it.

# %%
x = emp_left.drop(columns= ["Emp ID", "time_spend_company"])
y = emp_left.time_spend_company

# %%
import matplotlib.pyplot as plt
plt.style"classic"
# %matplotlib inline
import seaborn as sns
# Out:
#   File "<ipython-input-50-999f7de5be7a>", line 2
#     plt.style"classic"
#                      ^
# SyntaxError: invalid syntax

# %%
y.value_counts()
# Out:
# 3    1586
# 4     890
# 5     833
# 6     209
# 2      53
# Name: time_spend_company, dtype: int64

# %%
sns.set()
sns.distplot(y, kde = False)

# %%
sns.pairplot(x, hue ="dept", height = 2)
